# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10  \
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS
# 0       Independent          C1000    ProductDev   Association       1  \
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' 
application_df = application_df.drop(columns=["EIN"], axis=1)

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df.APPLICATION_TYPE.value_counts()
application_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of NAMES to be replaced to preseve RAM
# use the variable name `names_to_replace`
names_to_replace = list(application_counts[application_counts < 10].index)

# Replace in dataframe
for app in names_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(app,"Other")

# Check to make sure binning was successful
application_df['NAME'].value_counts()
# Out:
# NAME
# PARENT BOOSTER USA INC                                                  1260
# TOPS CLUB INC                                                            765
# UNITED STATES BOWLING CONGRESS INC                                       700
# WASHINGTON STATE UNIVERSITY                                              492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC                          408
#                                                                         ...
# ST LOUIS SLAM WOMENS FOOTBALL                                              1
# AIESEC ALUMNI IBEROAMERICA CORP                                            1
# WEALLBLEEDRED ORG INC                                                      1
# AMERICAN SOCIETY FOR STANDARDS IN MEDIUMSHIP & PSYCHICAL INVESTIGATI       1
# WATERHOUSE CHARITABLE TR                                                   1
# Name: count, Length: 19568, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df.CLASSIFICATION.value_counts()
classification_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts[classification_counts > 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_counts[classification_counts < 1000].index)


# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)

# Split our preprocessed data into our features and target arrays
X = application_df.drop(["IS_SUCCESSFUL"], axis=1).values
y = application_df["IS_SUCCESSFUL"].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])


nn = tf.keras.models.Sequential()

# create First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=number_input_features))



# xreate Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="relu"))


# create Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))


# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 80)                1569600
#
#  dense_4 (Dense)             (None, 30)                2430
#
#  dense_5 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 1572061 (6.00 MB)
# Trainable params: 1572061 (6.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.5045 - accuracy: 0.7538
# Epoch 2/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.1316 - accuracy: 0.9526
# Epoch 3/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.0981 - accuracy: 0.9606
# Epoch 4/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0940 - accuracy: 0.9619
# Epoch 5/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0932 - accuracy: 0.9611
# Epoch 6/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0925 - accuracy: 0.9617
# Epoch 7/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0912 - accuracy: 0.9619
# Epoch 8/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0906 - accuracy: 0.9624
# Epoch 9/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0898 - accuracy: 0.9633
# Epoch 10/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0891 - accuracy: 0.9633
# Epoch 11/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0884 - accuracy: 0.9640
# Epoch 12/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0880 - accuracy: 0.9633
# Epoch 13/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0875 - accuracy: 0.9640
# Epoch 14/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0869 - accuracy: 0.9642
# Epoch 15/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0859 - accuracy: 0.9652
# Epoch 16/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0861 - accuracy: 0.9652
# Epoch 17/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0856 - accuracy: 0.9648
# Epoch 18/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0853 - accuracy: 0.9655
# Epoch 19/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0848 - accuracy: 0.9653
# Epoch 20/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0842 - accuracy: 0.9657
# Epoch 21/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0840 - accuracy: 0.9663
# Epoch 22/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0836 - accuracy: 0.9661
# Epoch 23/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0830 - accuracy: 0.9663
# Epoch 24/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0825 - accuracy: 0.9668
# Epoch 25/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0822 - accuracy: 0.9670
# Epoch 26/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0822 - accuracy: 0.9664
# Epoch 27/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.0820 - accuracy: 0.9669
# Epoch 28/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.0816 - accuracy: 0.9669
# Epoch 29/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.0816 - accuracy: 0.9669
# Epoch 30/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0809 - accuracy: 0.9674
# Epoch 31/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0810 - accuracy: 0.9674
# Epoch 32/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0808 - accuracy: 0.9673
# Epoch 33/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0805 - accuracy: 0.9673
# Epoch 34/100
# 804/804 [==============================] - 12s 14ms/step - loss: 0.0799 - accuracy: 0.9677
# Epoch 35/100
# 804/804 [==============================] - 12s 14ms/step - loss: 0.0801 - accuracy: 0.9678
# Epoch 36/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.0799 - accuracy: 0.9674
# Epoch 37/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0793 - accuracy: 0.9678
# Epoch 38/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0795 - accuracy: 0.9680
# Epoch 39/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0796 - accuracy: 0.9681
# Epoch 40/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0792 - accuracy: 0.9679
# Epoch 41/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0789 - accuracy: 0.9677
# Epoch 42/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0786 - accuracy: 0.9682
# Epoch 43/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0792 - accuracy: 0.9675
# Epoch 44/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0785 - accuracy: 0.9682
# Epoch 45/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0783 - accuracy: 0.9684
# Epoch 46/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0782 - accuracy: 0.9682
# Epoch 47/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0781 - accuracy: 0.9683
# Epoch 48/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0775 - accuracy: 0.9684
# Epoch 49/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0782 - accuracy: 0.9687
# Epoch 50/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0779 - accuracy: 0.9682
# Epoch 51/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0774 - accuracy: 0.9684
# Epoch 52/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0773 - accuracy: 0.9689
# Epoch 53/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0772 - accuracy: 0.9686
# Epoch 54/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0771 - accuracy: 0.9684
# Epoch 55/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0771 - accuracy: 0.9684
# Epoch 56/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0772 - accuracy: 0.9686
# Epoch 57/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0768 - accuracy: 0.9688
# Epoch 58/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0771 - accuracy: 0.9682
# Epoch 59/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0766 - accuracy: 0.9688
# Epoch 60/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0771 - accuracy: 0.9687
# Epoch 61/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0767 - accuracy: 0.9687
# Epoch 62/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0766 - accuracy: 0.9689
# Epoch 63/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0764 - accuracy: 0.9687
# Epoch 64/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0763 - accuracy: 0.9685
# Epoch 65/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0765 - accuracy: 0.9687
# Epoch 66/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0761 - accuracy: 0.9690
# Epoch 67/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0761 - accuracy: 0.9690
# Epoch 68/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0761 - accuracy: 0.9689
# Epoch 69/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0766 - accuracy: 0.9689
# Epoch 70/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0763 - accuracy: 0.9688
# Epoch 71/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0758 - accuracy: 0.9689
# Epoch 72/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0759 - accuracy: 0.9689
# Epoch 73/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0760 - accuracy: 0.9686
# Epoch 74/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0757 - accuracy: 0.9689
# Epoch 75/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0768 - accuracy: 0.9688
# Epoch 76/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0758 - accuracy: 0.9688
# Epoch 77/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0754 - accuracy: 0.9691
# Epoch 78/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0758 - accuracy: 0.9692
# Epoch 79/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0755 - accuracy: 0.9689
# Epoch 80/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0755 - accuracy: 0.9692
# Epoch 81/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0753 - accuracy: 0.9689
# Epoch 82/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0758 - accuracy: 0.9690
# Epoch 83/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0755 - accuracy: 0.9693
# Epoch 84/100
# 804/804 [==============================] - 12s 14ms/step - loss: 0.0754 - accuracy: 0.9686
# Epoch 85/100
# 804/804 [==============================] - 12s 14ms/step - loss: 0.0753 - accuracy: 0.9687
# Epoch 86/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.0752 - accuracy: 0.9694
# Epoch 87/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0752 - accuracy: 0.9694
# Epoch 88/100
# 804/804 [==============================] - 12s 14ms/step - loss: 0.0752 - accuracy: 0.9688
# Epoch 89/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0752 - accuracy: 0.9692
# Epoch 90/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0751 - accuracy: 0.9691
# Epoch 91/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0753 - accuracy: 0.9693
# Epoch 92/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0754 - accuracy: 0.9691
# Epoch 93/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.0749 - accuracy: 0.9696
# Epoch 94/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0750 - accuracy: 0.9693
# Epoch 95/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0752 - accuracy: 0.9691
# Epoch 96/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0753 - accuracy: 0.9692
# Epoch 97/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0748 - accuracy: 0.9693
# Epoch 98/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0753 - accuracy: 0.9694
# Epoch 99/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0764 - accuracy: 0.9687
# Epoch 100/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0750 - accuracy: 0.9693

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.7832 - accuracy: 0.6870 - 746ms/epoch - 3ms/step
# Loss: 0.7831885814666748, Accuracy: 0.6869970560073853

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization3.h5")
# Out:
# c:\Users\Adwoa\anaconda3\envs\databootcamp\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
